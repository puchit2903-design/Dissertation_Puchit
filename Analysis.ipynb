# %% [markdown]
# **Analysis Script** (Regression and Residual)

# %% [markdown]
# Create dissertation_data folder and paste **analysis.py, spec_search.py, standardised_coefficients.py,players_cross_section.csv and, google_trends_monthly.csv**

# %%
# !pip install statsmodels scikit-learn -q
# %cd /content/dissertation_data
# !rm -rf analysis_outputs
# !python spec_search.py
# !python analysis.py
# !python standardised_coefficients.py
# Out:
# /content/dissertation_data
# pooled followers: 24 specifications written
# position followers: 23 specifications written
# trends: 52 specifications written
# engagement: 52 specifications written (best CV R2 = -0.002 — null finding)
# Done — comparison tables in analysis_outputs/.
# ...
# RUNNING DISSERTATION ANALYSIS
# ...
#
# [1] Load & prepare
#   Loaded /content/dissertation_data/players_cross_section.csv
#   144 players
#
# [2] Descriptives + attention by position
#                  n  mean_followers  median_followers  mean_trends  median_trends
# position_group
# Defender        34       5292486.0         3476229.0         1.90           1.49
# Forward         48      39278669.0         6240660.0         8.46           3.18
# Goalkeeper      12       6331612.0         2668147.0         2.15           1.57
# Midfielder      50       8323145.0         5411144.0         2.99           2.00
#
# [3b] Applying inclusion threshold (900 minutes)
# ...

# %%
import shutil
from google.colab import files

shutil.make_archive('/content/analysis_outputs', 'zip', '/content/dissertation_data/analysis_outputs')
files.download('/content/analysis_outputs.zip')
